# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "name": ["Ali", "Ali", "Omar", "Moussa"],
    "age": [20, 25, 30, 35],
    "city": ["Bamako", "Paris", "Dakar", "Lyon"]
})

df
# Out:
#      name  age    city
# 0     Ali   20  Bamako
# 1     Ali   25   Paris
# 2    Omar   30   Dakar
# 3  Moussa   35    Lyon

# %%
df.to_csv("../data/data.csv", index=False)

# %%
df[df["name"]=="Ali"].head(1)
# Out:
#   name  age    city
# 0  Ali   20  Bamako

# %%
df.loc[((df["name"]=="Ali") & (df["age"]>25)),['name','age']]="Abba",55
df.head()
# Out:
#      name  age    city
# 0     Ali   20  Bamako
# 1     Ali   25   Paris
# 2    Omar   30   Dakar
# 3  Moussa   35    Lyon

# %%
df.replace({"Abba":"Jean","Moussa":"Paul"})
# Out:
#    name  age    city
# 0   Ali   20  Bamako
# 1   Ali   25   Paris
# 2  Omar   30   Dakar
# 3  Paul   35    Lyon

# %%
print(df.name=="Ali")
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: name, dtype: bool

# %%
df[df.name=="Ali"].index
# Out:
# RangeIndex(start=0, stop=2, step=1)
